# %%
#string 
a="Yadav Pravin"
print(a)
# Out:
# Yadav Pravin

# %%
#int 
a=10
print(a)
# Out:
# 10

# %%
#boolean
a=True
print(a)
# Out:
# True

# %%
#tuple
i=("apple,banana,pineapple")
print(i)
# Out:
# apple,banana,pineapple

# %%
#list
a=["apple,banana,cherry"]
print(a)
# Out:
# ['apple,banana,cherry']

# %%
#dict
a=("Name,john,age,35")
print(a)
# Out:
# Name,john,age,35

# %%
#none
a=
print(a)
# Out:
#   Cell In[7], line 2
#     a=
#       ^
# SyntaxError: invalid syntax

# %%
#coplex
a=1j
print(a)
# Out:
# 1j

# %%
#float
a=4.004
print(a)
# Out:
# 4.004

# %%
#set
x={"apple","banana","cherry"}
print(x)
# Out:
# {'apple', 'cherry', 'banana'}

# %%
#frozenset
x=({"apple","banana","cherry"})
print(x)
# Out:
# {'apple', 'cherry', 'banana'}
